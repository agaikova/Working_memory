# %%
import sys
sys.path.append('../')

# %%
import ctn_benchmark

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from hyperopt import fmin, hp, tpe, Trials, rand
import pickle
import hyperopt

# %%
import wm_benchmark_00
reload(wm_benchmark_00)
# Out:
# <module 'wm_benchmark_00' from '../wm_benchmark_00.pyc'>

# %%
def objective(x):
    vals = wm_benchmark_00.Working_Memory().run(
        #input_scale = x['input_scale'],
        #intercept_low = x['intercept_low'],
        #intercept_high = x['intercept_high'],
        #tau_input = x['tau_input'],
        #tau_recurrent = x['tau_recurrent'],
        tau_reset = x['tau_reset'],
        #max_rate_high = x['max_rate_high'],
        #max_rate_low = x['max_rate_low']
    )
    return{
        'loss':
            abs(vals['act_510'] - 28) + abs(vals['act_1750'] - 33) + abs(vals['peak'] - 53),
        'status':hyperopt.STATUS_OK,
    }
trials = Trials()
best = fmin(objective,
           space = {#'input_scale':hp.uniform('input_scale', 0.1, 10),
                    #'intercept_low':hp.uniform('intercept_low', -0.5, 0.5),
                    #'intercept_high':hp.uniform('intercept_high', 0.5, 1.0),
                    #'tau_input':hp.uniform('tau_input', 0.002, 0.2),
                    #'tau_recurrent':hp.uniform('tau_recurrent', 0.002, 0.2),
                    'tau_reset':hp.uniform('tau_reset', 0.002, 0.2),
                    #'max_rate_high':hp.uniform('max_rate_high', 150, 250),
                    #'max_rate_low':hp.uniform('max_rate_low', 100, 150)
                   },
           algo = hyperopt.tpe.suggest,
           max_evals = 100,
           trials = trials
           )
pickle.dump({'Trials':trials, 'Best':best}, open('wm_data_tau_reset', 'w'))
# Out:
# running Working_Memory#20160809-103438-5b083cd6
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1399008987483766
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103442-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.023000851379037082
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103446-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.10233175027691487
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103449-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.02282408118909969
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103453-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.10571899735102583
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103457-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1735941344843788
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103501-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.11496526177879055
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103504-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.03004279327719466
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103508-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1307304138834063
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103512-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1566189719609083
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103516-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.08506270603704372
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103519-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.16265791800909982
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103523-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.132943130605093
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103528-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.032336755506159734
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103532-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.18888234120768987
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103536-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1503697677411004
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103539-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.09921055272970554
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103543-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.15008529226627804
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103547-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.18364232582242648
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103551-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.18060818191287664
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103555-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.13763892724799817
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103600-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.19960058530253966
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103603-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.06390643160025564
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103608-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.07130091460606613
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103612-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.04925805306123272
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103617-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.004835297132642316
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103622-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.07491191514850831
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103627-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.05849408762679941
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103630-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.11975001057250848
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103634-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.08973901142950105
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103638-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.050719890647722234
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103644-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.12428137644998404
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103648-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.09094465457714752
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103652-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.003875532342906801
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103656-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.11215452454546632
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103700-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.19966956351712478
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103704-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.14133507389784233
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103707-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1674417773360001
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103711-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1983538308175415
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103715-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.17306414031228223
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103718-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.017257434392997886
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103722-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.10724218044157591
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103726-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.07935819866231439
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103729-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.039203386484861436
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103733-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.09959995755194759
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103737-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.04737825947321545
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103740-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.011630175797234885
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103744-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1488449854866306
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103749-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.08204051079478242
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103754-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.12747768961010933
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103758-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.057679260315827735
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103802-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.02436718174493007
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103806-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1559274058155158
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103810-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.11790290460001052
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103815-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.13878882854298694
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103819-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.09771868242645168
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103822-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.03869947077184052
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103826-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.06899674227121973
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103830-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.12515892743370485
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103835-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.16128351204557825
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103840-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.0918992029919991
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103844-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.19039806477073196
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103848-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.14544485189001818
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103852-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.17750263341681843
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103855-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1111230012207778
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103859-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.19271041265023398
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103903-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1389677173924942
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103906-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.16862726319135632
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103910-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.16963532666093473
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103914-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1320687274964667
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103918-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1581869521705991
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103921-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.06120839058158126
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103925-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.05630792943541394
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103929-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.02364289776301884
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103933-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1512395144176178
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103937-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.11787626592748057
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103941-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.10579433973077279
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103944-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.13619430280036296
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103948-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.09483889676783233
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103952-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.03969081777312677
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103955-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.06990515269554858
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-103959-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.03918026259445736
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104003-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.12546763457055074
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104006-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.17984025853386384
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104010-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.08846862043990156
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104014-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.15995935490462856
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104017-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.19384271784113008
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104021-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.14947114258956673
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104025-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.17741238887872002
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104028-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.16514424090708468
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104032-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.11052638517922124
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104036-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1839004014549004
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104040-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.14384794419575386
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104044-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.15440708024189553
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104047-2dc82a53
# Simulation finished in 0:00:02.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.17159528148034983
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104052-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.1863244351619544
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104055-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.12098829486461085
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104059-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.13359883804423112
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104101-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.13196408210419067
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137
# running Working_Memory#20160809-104104-2dc82a53
# Simulation finished in 0:00:01.
# _dimensions = 10
# _input_scale = 0.38314316705290097
# _n_neurons_per_dim = 50
# _intercept_low = -0.4989080091138938
# _intercept_high = 0.5963158879085206
# _tau_input = 0.009683186948674292
# _tau_recurrent = 0.1959772077772586
# _tau_reset = 0.06381424392660391
# _max_rate_high = 225.01822297425895
# _max_rate_low = 130.69268975236358
# _sensory_delay = 0.05
# _reset_scale = 0.3
# _filter_threshold = 0.0
# _backend = 'nengo'
# _dt = 0.001
# _seed = 1
# _hide_overlay = False
# _gui = False
# N = 265
# act_1750 = 43.350698811778486
# act_510 = 24.799945381925422
# peak = 51.262139750327137

# %%
print(best)
# Out:
# {'tau_reset': 0.1399008987483766}

# %%
import pandas
import seaborn as sns
data = ctn_benchmark.Data('data')
df = pandas.DataFrame(data.data)
df = df[df._input_scale == 0.38314316705290097]
df = df[df._intercept_low == -0.4989080091138938]
df = df[df._tau_recurrent == 0.1959772077772586]
df = df[df._tau_input == 0.009683186948674292]
df = df[df._max_rate_high == 225.01822297425895]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols = 3, sharey = True)
x = '_tau_reset'
sns.regplot(x, y = 'act_510', ax = ax1, data = df)
sns.regplot(x, y = 'act_1750', ax = ax2, data = df)
sns.regplot(x, y = 'peak', ax = ax3, data = df)

# %% [markdown]
# It looks like this particular parameter does not affect anything directly. Cool.
